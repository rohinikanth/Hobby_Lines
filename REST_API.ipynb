# %% [markdown]
# GET Request

# %%
import os
import requests

url='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%205/data/Example1.txt'

path=os.path.join(os.getcwd(),'Example1.txt')
r=requests.get(url)
with open(path,'wb') as f:
  f.write(r.content)

# %%
#Get Request with URL Parameter

url_get='http://httpbin.org/get'
payload={"name":"Joseph","ID":"388"}
r_get=requests.get(url_get,params=payload)
r_get.url
# Out:
# 'http://httpbin.org/get?name=Joseph&ID=388'

# %%
print("request body:", r_get.request.body)
print(r_get.status_code)
print("Text:",r.text)
# Out:
# request body: None
# 200
# Text: {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "ID": "388",
#     "name": "Joseph"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate, zstd",
#     "Content-Length": "18",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.3",
#     "X-Amzn-Trace-Id": "Root=1-68405b34-36d0c016528cd6b12d24a5fd"
#   },
#   "json": null,
#   "origin": "34.148.214.139",
#   "url": "http://httpbin.org/post"
# }

# %%
r.headers['Content-Type']
# Out:
# 'application/json'

# %%
# 'Content-Type' is in the JSON format we can use the method json(), it returns a Python dict
r.json
# Out:
# <bound method Response.json of <Response [200]>>

# %%
#The key args has the name and values:
r_get.json()['args']
# Out:
# {'ID': '388', 'name': 'Joseph'}

# %% [markdown]
# POST Requests

# %%
url_post='http://httpbin.org/post'
'''
Endpoint will expect data as a file or as a form.
A form is convenient way to configure an HTTP request to send data to a server.
To make a POST request we use the post() function, the variable payload is passed to the parameter  data
'''
r_post=requests.post(url_post,data=payload)
r_post.url
# Out:
# 'http://httpbin.org/post'

# %%
print("POST request body:",r_post.request.body)
print("GET request body:",r_get.request.body)
# Out:
# POST request body: name=Joseph&ID=388
# GET request body: None

# %%
r_post.json()['form']
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/requests/models.py in json(self, **kwargs)
#     973         try:
# --> 974             return complexjson.loads(self.text, **kwargs)
#     975         except JSONDecodeError as e:
#
# /usr/local/lib/python3.11/dist-packages/simplejson/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, use_decimal, allow_nan, **kw)
#     513             and not use_decimal and not allow_nan and not kw):
# --> 514         return _default_decoder.decode(s)
#     515     if cls is None:
#
# /usr/local/lib/python3.11/dist-packages/simplejson/decoder.py in decode(self, s, _w, _PY3)
#     385             s = str(s, self.encoding)
# --> 386         obj, end = self.raw_decode(s)
#     387         end = _w(s, end).end()
#
# ...

# %%
#REFERENCE
https://requests.readthedocs.io/en/latest/?utm_content=000026UJ&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2021-01-01&utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_term=10006555

# %% [markdown]
# WEB SCRAPPING
#
#
# 1.  Email address gathering: Many companies that use email as a medium for marketing, use web scraping to collect email ID and then send bulk emails.
# 2. Price Comparison: Services such as ParseHub use web scraping to collect data from online shopping websites and use it to compare the prices of products.
# 3. Social Media Scraping: Web scraping is used to collect data from Social Media websites such as Twitter to find out what's trending.

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://en.wikipedia.org/wiki/Google'

# Send an HTTP GET request to the webpage
response = requests.get(url)

# Store the HTML content in a variable
html_content = response.text

# Create a BeautifulSoup object to parse the HTML
soup = BeautifulSoup(html_content, 'html.parser')

# Display a snippet of the HTML content
print(html_content[:500])
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vect

# %%
# Find all <a> tags (anchor tags) in the HTML
links = soup.find_all('a')

# Iterate through the list of links and print their text
for link in links:
    print(link.text)
# Out:
# Jump to content
# Main page
# Contents
# Current events
# Random article
# About Wikipedia
# Contact us
# Help
# Learn to edit
# Community portal
# Recent changes
# Upload file
# Special pages
#
#
#
#
#
#
#
#
# Search
#
# Donate
# Create account
# Log in
# Donate
#  Create account
#  Log in
# learn more
# Contributions
# Talk
#
# (Top)
#
#
#
# 1
# History
#
#
#
#
# 1.1
# Early years
#
#
#
#
# 1.2
# Growth
#
#
#
#
# 1.3
# Initial public offering
#
#
#
#
# 1.4
# 2012 onwards
#
#
#
#
# 2
# Products and services
#
#
#
#
# 2.1
# Search engine
#
#
#
#
# 2.2
# Advertising
#
#
#
#
# 2.3
# Generative artificial intelligence
#
#
#
#
# 2.4
# Consumer services
#
#
#
#
# 2.4.1
# Web-based services
#
#
#
#
# 2.4.2
# Software
#
#
#
#
# 2.4.3
# Hardware
#
#
#
#
# 2.5
# Enterprise services
#
#
#
#
# 2.6
# Internet services
#
#
#
#
# 2.7
# Financial services
#
#
#
#
# 3
# Corporate affairs
#
#
#
#
# 3.1
# Stock price performance and quarterly earnings
#
#
#
#
# 3.2
# Tax avoidance strategies
#
#
#
#
# ...

# %%
# !pip install scrapy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 321.8/321.8 kB 8.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 51.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.8/259.8 kB 15.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.4/107.4 kB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 5.1 MB/s eta 0:00:00
# ...

# %%
# Scrapy is an open-source and collaborative web crawling framework for Python.
import scrapy
class QuotesSpider(scrapy.Spider):
    name = "quotes"
    start_urls = ['http://quotes.toscrape.com/tag/humor/',]
    def parse(self, response):
        for quote in response.css('div.quote'):
            yield {'quote': quote.css('span.text::text').get()}

# %%
# !pip install selenium
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 43.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 499.2/499.2 kB 24.4 MB/s eta 0:00:00
# ...

# %%
#Selenium is a tool used for controlling web browsers through programs and automating browser tasks.
from selenium import webdriver
driver = webdriver.Chrome()
driver.get("http://www.example.com")

# %% [markdown]
# Get Methods
#
# RandomUser &  Fruityvice API

# %%
# !pip install randomuser
# !pip install pandas
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for randomuser: filename=randomuser-1.6-py3-none-any.whl size=5067 sha256=3d1f1af050029580c31340ddeb33f7d1c392373f8656aa6019ec714b6d21f077
#   Stored in directory: /root/.cache/pip/wheels/fc/8d/74/bcdd5e8a9433bfa4c4f9c1cccbfec40139322a28d77f61e45e
# Successfully built randomuser
# ...

# %%
from randomuser import RandomUser
import pandas as pd

r = RandomUser()

user_list = r.generate_users(15)
print(user_list,end = '\n')
# Out:
# [<randomuser.RandomUser object at 0x7d0da90d2fd0>, <randomuser.RandomUser object at 0x7d0da90d3010>, <randomuser.RandomUser object at 0x7d0da90d3050>, <randomuser.RandomUser object at 0x7d0da90d3090>, <randomuser.RandomUser object at 0x7d0da90d30d0>, <randomuser.RandomUser object at 0x7d0da90d3150>, <randomuser.RandomUser object at 0x7d0da90d3190>, <randomuser.RandomUser object at 0x7d0da90d31d0>, <randomuser.RandomUser object at 0x7d0da90d3210>, <randomuser.RandomUser object at 0x7d0da90d3110>, <randomuser.RandomUser object at 0x7d0da90d3250>, <randomuser.RandomUser object at 0x7d0da90d3290>, <randomuser.RandomUser object at 0x7d0da90d32d0>, <randomuser.RandomUser object at 0x7d0da90d3310>, <randomuser.RandomUser object at 0x7d0da90d3350>]

# %%
r.get_first_name()
# Out:
# 'Saana'

# %%
r.get_info()
# Out:
# {'seed': '9a5960b38635d0f1', 'results': 1, 'page': 1, 'version': '1.3'}

# %%
r.get_cell()
# Out:
# '041-782-24-98'

# %%
names = r.get_full_name()

# %%
for user in user_list:
    print (user.get_full_name()," ",user.get_email()," ",user.get_cell()," ",user.get_picture())
# Out:
# Carina Hallan   carina.hallan@example.com   44592277   https://randomuser.me/api/portraits/women/7.jpg
# Louisa Roche   louisa.roche@example.com   06-03-58-76-70   https://randomuser.me/api/portraits/women/21.jpg
# Frank Roche   frank.roche@example.com   077 994 42 41   https://randomuser.me/api/portraits/men/71.jpg
# Vildan Arıcan   vildan.arican@example.com   (350)-149-0905   https://randomuser.me/api/portraits/women/56.jpg
# Gabriëlla Van Tuil   gabriella.vantuil@example.com   (06) 64273621   https://randomuser.me/api/portraits/women/41.jpg
# Nina Johnson   nina.johnson@example.com   (658)-871-7344   https://randomuser.me/api/portraits/women/6.jpg
# Angus Robinson   angus.robinson@example.com   (867)-865-8261   https://randomuser.me/api/portraits/men/4.jpg
# Yasemin Pektemek   yasemin.pektemek@example.com   (974)-035-2429   https://randomuser.me/api/portraits/women/83.jpg
# Mehmet Polat   mehmet.polat@example.com   (871)-197-7067   https://randomuser.me/api/portraits/men/40.jpg
# ...

# %%
def get_users():
    users =[]

    for user in user_list:
        users.append({"Name":user.get_full_name(),"Gender":user.get_gender(),"City":user.get_city(),"State":user.get_state(),"Email":user.get_email(), "DOB":user.get_dob(),"Picture":user.get_picture()})

    return pd.DataFrame(users)

# %%
get_users()
# Out:
#                   Name  Gender               City                State  \
# 0        Carina Hallan  female            Geithus        Sør-Trøndelag
# 1         Louisa Roche  female             Rennes         Eure-et-Loir
# 2          Frank Roche    male               Giez               Genève
# 3        Vildan Arıcan  female           Erzincan              Bayburt
# 4   Gabriëlla Van Tuil  female        Kogerpolder        Noord-Holland
# 5         Nina Johnson  female             Nelson             Auckland
# 6       Angus Robinson    male           Auckland            Southland
# 7     Yasemin Pektemek  female              Adana                 Ağrı
# 8         Mehmet Polat    male         Kırklareli            Kırıkkale
# 9          Louise King  female          Traralgon    Western Australia
# 10     Hannah Sønsteby  female            Torvika             Akershus
# 11       Alão Oliveira    male     Angra dos Reis              Sergipe
# ...

# %%
df1 = pd.DataFrame(get_users())

# %%
import requests
import json

#Fruityvice API
data =requests.get("https://fruityvice.com/api/fruit/all")
out = json.loads(data.text)

pd.DataFrame(out)
# Out:
#                   name   id           family             order         genus  \
# 0            Persimmon   52        Ebenaceae           Rosales     Diospyros
# 1           Strawberry    3         Rosaceae           Rosales      Fragaria
# 2               Banana    1         Musaceae      Zingiberales          Musa
# 3               Tomato    5       Solanaceae         Solanales       Solanum
# 4                 Pear    4         Rosaceae           Rosales         Pyrus
# 5               Durian   60        Malvaceae          Malvales         Durio
# 6           Blackberry   64         Rosaceae           Rosales         Rubus
# 7          Lingonberry   65        Ericaceae          Ericales     Vaccinium
# 8                 Kiwi   66    Actinidiaceae  Struthioniformes       Apteryx
# 9               Lychee   67      Sapindaceae        Sapindales        Litchi
# 10           Pineapple   10     Bromeliaceae            Poales        Ananas
# ...

# %%
df2 = pd.json_normalize(out)

# %%
df2
# Out:
#                   name   id           family             order         genus  \
# 0            Persimmon   52        Ebenaceae           Rosales     Diospyros
# 1           Strawberry    3         Rosaceae           Rosales      Fragaria
# 2               Banana    1         Musaceae      Zingiberales          Musa
# 3               Tomato    5       Solanaceae         Solanales       Solanum
# 4                 Pear    4         Rosaceae           Rosales         Pyrus
# 5               Durian   60        Malvaceae          Malvales         Durio
# 6           Blackberry   64         Rosaceae           Rosales         Rubus
# 7          Lingonberry   65        Ericaceae          Ericales     Vaccinium
# 8                 Kiwi   66    Actinidiaceae  Struthioniformes       Apteryx
# 9               Lychee   67      Sapindaceae        Sapindales        Litchi
# 10           Pineapple   10     Bromeliaceae            Poales        Ananas
# ...

# %%
blueberry = df2.loc[df2["name"] == 'Blueberry']
blueberry
# Out:
#          name  id    family    order     genus  nutritions.calories  \
# 21  Blueberry  33  Rosaceae  Rosales  Fragaria                   29
#
#     nutritions.fat  nutritions.sugar  nutritions.carbohydrates  \
# 21             0.4               5.4                       5.5
#
#     nutritions.protein
# 21                 0.0

# %%
print(blueberry.iloc[0]['family'])
print(blueberry.iloc[0]['order'])
print(blueberry.iloc[0]['genus'])
# Out:
# Rosaceae
# Rosales
# Fragaria

# %%
bananna = df2.loc[df2["name"]=='Banana']
print(bananna.iloc[0]['nutritions.calories'])
# Out:
# 96

# %% [markdown]
# ***Open Public APIs ***
#
# https://mixedanalytics.com/blog/list-actually-free-open-no-auth-needed-apis/
